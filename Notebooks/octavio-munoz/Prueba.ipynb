# %%
import sys

print(sys.executable)
# Out:
# c:\Users\Octavio_M\DPL_Python\Herrta-Entornos-CS-Datos\ia-produccion-2\.venv\Scripts\python.exe

# %%
print("Mi primer Notebook funciona correctamente")
# Out:
# Mi primer Notebook funciona correctamente
