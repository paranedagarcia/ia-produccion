# %%
import pandas as pd

df = pd.read_excel("../plan_de_compras_2025.xlsx")

print("Archivo cargado correctamente")
print("Cantidad de filas y columnas:", df.shape)
# Out:
# Archivo cargado correctamente
# Cantidad de filas y columnas: (831, 26)

# %%
df.head()
# Out:
#                           Unidad de Compra   ID Proyecto  \
# 0  Ministerio de Vivienda y Urbanismo(766)  587-259-PC22
# 1                    SEREMI MINVU V REGION   632-28-PC22
# 2                    SEREMI MINVU V REGION   632-32-PC22
# 3                    SEREMI MINVU V REGION   632-34-PC22
# 4                    SEREMI MINVU V REGION   632-41-PC22
#
#           Tipo Proyecto Estado Proyecto Código presupuestario  \
# 0  Proyecto estratégico       Publicado          2207-2209-33
# 1  Proyecto operacional       Publicado          2206-2206001
# 2  Proyecto operacional       Publicado               2204001
# 3  Proyecto operacional       Publicado               2209006
# 4  Proyecto operacional       Publicado               2205005
#
#                                      Nombre Proyecto  \
# 0  Servicio arriendo de una plataforma de gestión...
# 1  Servicio de Mantención y Reparaciones Menores ...
# 2           Servicios de Impresión-Seremi Valparaiso
# ...

# %%
df.columns.tolist()
# Out:
# ['Unidad de Compra',
#  'ID Proyecto',
#  'Tipo Proyecto',
#  'Estado Proyecto',
#  'Código presupuestario',
#  'Nombre Proyecto',
#  'Descripción Proyecto',
#  'Cantidad de Ítems',
#  'Nombre ítem',
#  'Tipo compra',
#  'Cantidad Productos',
#  'Monto Unitario Ítem',
#  'Monto Total Ítem Año 2025',
#  'Cantidad OC',
#  'Meses envío OC',
#  'Nombre responsable',
#  'Cargo responsable',
#  'Teléfono responsable',
#  'Correo responsable',
#  'Fecha de Inicio Compra',
#  'Fecha Publicación PAC 2025',
#  'Cantidad OC Asociadas Ítem 2025',
#  'OC Asociada Item 2025',
#  'Item De Arraste',
#  'Monto De Arrastre',
#  'Meses envio OC de Arraste']

# %%
df.columns.tolist()
# Out:
# ['Unidad de Compra',
#  'ID Proyecto',
#  'Tipo Proyecto',
#  'Estado Proyecto',
#  'Código presupuestario',
#  'Nombre Proyecto',
#  'Descripción Proyecto',
#  'Cantidad de Ítems',
#  'Nombre ítem',
#  'Tipo compra',
#  'Cantidad Productos',
#  'Monto Unitario Ítem',
#  'Monto Total Ítem Año 2025',
#  'Cantidad OC',
#  'Meses envío OC',
#  'Nombre responsable',
#  'Cargo responsable',
#  'Teléfono responsable',
#  'Correo responsable',
#  'Fecha de Inicio Compra',
#  'Fecha Publicación PAC 2025',
#  'Cantidad OC Asociadas Ítem 2025',
#  'OC Asociada Item 2025',
#  'Item De Arraste',
#  'Monto De Arrastre',
#  'Meses envio OC de Arraste']

# %%
df.dtypes
# Out:
# Unidad de Compra                              str
# ID Proyecto                                   str
# Tipo Proyecto                                 str
# Estado Proyecto                               str
# Código presupuestario                      object
# Nombre Proyecto                               str
# Descripción Proyecto                          str
# Cantidad de Ítems                           int64
# Nombre ítem                                   str
# Tipo compra                                 int64
# Cantidad Productos                          int64
# Monto Unitario Ítem                         int64
# Monto Total Ítem Año 2025                   int64
# Cantidad OC                                 int64
# Meses envío OC                             object
# Nombre responsable                            str
# Cargo responsable                             str
# Teléfono responsable                       object
# Correo responsable                            str
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 831 entries, 0 to 830
# Data columns (total 26 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Unidad de Compra                 831 non-null    str
#  1   ID Proyecto                      831 non-null    str
#  2   Tipo Proyecto                    831 non-null    str
#  3   Estado Proyecto                  831 non-null    str
#  4   Código presupuestario            830 non-null    object
#  5   Nombre Proyecto                  831 non-null    str
#  6   Descripción Proyecto             831 non-null    str
#  7   Cantidad de Ítems                831 non-null    int64
#  8   Nombre ítem                      831 non-null    str
#  9   Tipo compra                      831 non-null    int64
#  10  Cantidad Productos               831 non-null    int64
#  11  Monto Unitario Ítem              831 non-null    int64
# ...

# %%
df.isnull().sum()
# Out:
# Unidad de Compra                     0
# ID Proyecto                          0
# Tipo Proyecto                        0
# Estado Proyecto                      0
# Código presupuestario                1
# Nombre Proyecto                      0
# Descripción Proyecto                 0
# Cantidad de Ítems                    0
# Nombre ítem                          0
# Tipo compra                          0
# Cantidad Productos                   0
# Monto Unitario Ítem                  0
# Monto Total Ítem Año 2025            0
# Cantidad OC                          0
# Meses envío OC                       0
# Nombre responsable                   0
# Cargo responsable                    0
# Teléfono responsable                 0
# Correo responsable                   0
# Fecha de Inicio Compra               0
# Fecha Publicación PAC 2025           0
# Cantidad OC Asociadas Ítem 2025      0
# OC Asociada Item 2025              123
# Item De Arraste                      0
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.dtypes
# Out:
# Unidad de Compra                              str
# ID Proyecto                                   str
# Tipo Proyecto                                 str
# Estado Proyecto                               str
# Código presupuestario                      object
# Nombre Proyecto                               str
# Descripción Proyecto                          str
# Cantidad de Ítems                           int64
# Nombre ítem                                   str
# Tipo compra                                 int64
# Cantidad Productos                          int64
# Monto Unitario Ítem                         int64
# Monto Total Ítem Año 2025                   int64
# Cantidad OC                                 int64
# Meses envío OC                             object
# Nombre responsable                            str
# Cargo responsable                             str
# Teléfono responsable                       object
# Correo responsable                            str
# ...

# %%
df.isnull().sum()
# Out:
# Unidad de Compra                     0
# ID Proyecto                          0
# Tipo Proyecto                        0
# Estado Proyecto                      0
# Código presupuestario                1
# Nombre Proyecto                      0
# Descripción Proyecto                 0
# Cantidad de Ítems                    0
# Nombre ítem                          0
# Tipo compra                          0
# Cantidad Productos                   0
# Monto Unitario Ítem                  0
# Monto Total Ítem Año 2025            0
# Cantidad OC                          0
# Meses envío OC                       0
# Nombre responsable                   0
# Cargo responsable                    0
# Teléfono responsable                 0
# Correo responsable                   0
# Fecha de Inicio Compra               0
# Fecha Publicación PAC 2025           0
# Cantidad OC Asociadas Ítem 2025      0
# OC Asociada Item 2025              123
# Item De Arraste                      0
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 831 entries, 0 to 830
# Data columns (total 26 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Unidad de Compra                 831 non-null    str
#  1   ID Proyecto                      831 non-null    str
#  2   Tipo Proyecto                    831 non-null    str
#  3   Estado Proyecto                  831 non-null    str
#  4   Código presupuestario            830 non-null    object
#  5   Nombre Proyecto                  831 non-null    str
#  6   Descripción Proyecto             831 non-null    str
#  7   Cantidad de Ítems                831 non-null    int64
#  8   Nombre ítem                      831 non-null    str
#  9   Tipo compra                      831 non-null    int64
#  10  Cantidad Productos               831 non-null    int64
#  11  Monto Unitario Ítem              831 non-null    int64
# ...

# %%
df.isnull().sum()
# Out:
# Unidad de Compra                     0
# ID Proyecto                          0
# Tipo Proyecto                        0
# Estado Proyecto                      0
# Código presupuestario                1
# Nombre Proyecto                      0
# Descripción Proyecto                 0
# Cantidad de Ítems                    0
# Nombre ítem                          0
# Tipo compra                          0
# Cantidad Productos                   0
# Monto Unitario Ítem                  0
# Monto Total Ítem Año 2025            0
# Cantidad OC                          0
# Meses envío OC                       0
# Nombre responsable                   0
# Cargo responsable                    0
# Teléfono responsable                 0
# Correo responsable                   0
# Fecha de Inicio Compra               0
# Fecha Publicación PAC 2025           0
# Cantidad OC Asociadas Ítem 2025      0
# OC Asociada Item 2025              123
# Item De Arraste                      0
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
nulos = df.isnull().sum()

resumen_nulos = pd.DataFrame({
    "Columna": nulos.index,
    "Valores Nulos": nulos.values
})

resumen_nulos = resumen_nulos[resumen_nulos["Valores Nulos"] > 0]

resumen_nulos
# Out:
#                       Columna  Valores Nulos
# 4       Código presupuestario              1
# 22      OC Asociada Item 2025            123
# 25  Meses envio OC de Arraste            648

# %%
df.describe()
# Out:
#        Cantidad de Ítems  Tipo compra  Cantidad Productos  \
# count         831.000000   831.000000               831.0
# mean            1.199759     4.657040                 1.0
# min             1.000000     1.000000                 1.0
# 25%             1.000000     4.000000                 1.0
# 50%             1.000000     6.000000                 1.0
# 75%             1.000000     6.000000                 1.0
# max             3.000000     6.000000                 1.0
# std             0.414845     1.942318                 0.0
#
#        Monto Unitario Ítem  Monto Total Ítem Año 2025  Cantidad OC  \
# count         8.310000e+02               8.310000e+02   831.000000
# mean          1.085214e+08               1.014853e+08     1.344164
# min           9.000000e+04               0.000000e+00     1.000000
# 25%           4.200000e+06               3.000000e+06     1.000000
# 50%           4.000000e+07               3.500000e+07     1.000000
# ...

# %%
df["Tipo Proyecto"].value_counts()
# Out:
# Tipo Proyecto
# Proyecto operacional    613
# Proyecto estratégico    218
# Name: count, dtype: int64

# %%
df["Estado Proyecto"].value_counts()
# Out:
# Estado Proyecto
# Actualizado    648
# Publicado      183
# Name: count, dtype: int64

# %%
df["Tipo compra"].value_counts()
# Out:
# Tipo compra
# 6    486
# 1    159
# 4     83
# 5     79
# 3     20
# 2      4
# Name: count, dtype: int64

# %%
df["Unidad de Compra"].value_counts().head(10)
# Out:
# Unidad de Compra
# Ministerio de Vivienda y Urbanismo(766)    684
# SEREMI MINVU V REGION                       30
# SEREMI MINVU III REGION                     25
# SEREMI MINVU VI REGION                      20
# SEREMI IV REGION                            14
# SEREMI MINVU REGION ARICA Y PARINACOTA       9
# SEREMI MINVU XI REGION                       8
# SEREMI MINVU II REGION                       8
# SEREMI MINVU I REGION                        7
# SEREMI VIII REGION                           6
# Name: count, dtype: int64

# %%
df["Tipo Proyecto"].value_counts()
# Out:
# Tipo Proyecto
# Proyecto operacional    613
# Proyecto estratégico    218
# Name: count, dtype: int64

# %%
df["Estado Proyecto"].value_counts()
# Out:
# Estado Proyecto
# Actualizado    648
# Publicado      183
# Name: count, dtype: int64

# %%
df["Tipo compra"].value_counts()
# Out:
# Tipo compra
# 6    486
# 1    159
# 4     83
# 5     79
# 3     20
# 2      4
# Name: count, dtype: int64

# %%
df["Unidad de Compra"].value_counts().head(10)
# Out:
# Unidad de Compra
# Ministerio de Vivienda y Urbanismo(766)    684
# SEREMI MINVU V REGION                       30
# SEREMI MINVU III REGION                     25
# SEREMI MINVU VI REGION                      20
# SEREMI IV REGION                            14
# SEREMI MINVU REGION ARICA Y PARINACOTA       9
# SEREMI MINVU XI REGION                       8
# SEREMI MINVU II REGION                       8
# SEREMI MINVU I REGION                        7
# SEREMI VIII REGION                           6
# Name: count, dtype: int64
